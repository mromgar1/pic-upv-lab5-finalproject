# %% [markdown]
# # FINAL PROJECT

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td
import gplugins.tidy3d as gt
import gplugins.tidy3d.materials as mat
from gplugins import plot
from gplugins.common.config import PATH

from upvfab_design_tools import MMI_EME, DC_EME

nm = 1e-3
wavelength = np.linspace(1500, 1600) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ## MMI'S

# %%
mmi_body_w = 10
lambda_c = 1.55

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=220 * nm, # MMI Body height 
    slab_thickness=0, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='si', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=2, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.2, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.plot_index()
pol = mmi_body_waveguide.fraction_te
print(f'Fracción TE: {pol}')
mmi_body_waveguide.n_eff
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 11:29:01 CEST WARNING: The group index was not computed. To calculate group
#               index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-04-07 11:29:01.112 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_ba674253ef027ebd.npz.
# Fracción TE: [0.99999775 0.99999095]
# array([2.88957722+1.85314893e-05j, 2.88647276+1.85597487e-05j])

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 249.64121650540767

# %% [markdown]
# ### Mesh

# %%
n_steps = 7
grid_resolution = np.linspace(20,80,n_steps)
res_neff = []
print(grid_resolution)

for i in range(n_steps): 
    mmi_body_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=mmi_body_w, # MMI Body width
        core_thickness=220 * nm, # MMI Body height 
        slab_thickness=0, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
        # Materials
        core_material='si', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=lambda_c, # Wavelength to simulate
        num_modes=1, # Targeted number of modes to find - Higher than before! It's a multimode section
        max_grid_scaling=1.2, # Parameters of the grid
        grid_resolution=grid_resolution[i], # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= mmi_body_waveguide.n_eff.real
    res_neff.append(n_eff)

res_neff=np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"Grid resolution vs n_eff")
plt.xlabel("Grid resolution")
plt.ylabel("neff")
plt.grid()
plt.plot(grid_resolution, res_neff)
# Out:
# [20. 30. 40. 50. 60. 70. 80.]
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 11:33:33.277 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_6487102fef4eee11.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 11:37:17.886 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_3fa718571338cf70.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 11:44:19.873 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_b8bc748ea71c0515.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 11:54:39.554 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_fab7e9b53cf7e31d.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 12:13:47.706 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_5541d3135bd64664.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 12:42:37.133 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_ccfeb0473d66cfdf.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 12:59:11.348 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_66e9140e4875b45b.npz.

# %%
n_steps = 5
max_grid_scaling = np.linspace(1.4,1.8,n_steps)
res_neff = []
print(grid_resolution)

for i in range(n_steps): 
    mmi_body_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=mmi_body_w, # MMI Body width
        core_thickness=220 * nm, # MMI Body height 
        slab_thickness=0, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
        # Materials
        core_material='si', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=lambda_c, # Wavelength to simulate
        num_modes=1, # Targeted number of modes to find - Higher than before! It's a multimode section
        max_grid_scaling=max_grid_scaling[i], # Parameters of the grid
        grid_resolution=55, # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= mmi_body_waveguide.n_eff.real
    res_neff.append(n_eff)

res_neff=np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"max_grid_scaling vs n_eff")
plt.xlabel("max_grid_scaling")
plt.ylabel("neff")
plt.grid()
plt.plot(max_grid_scaling, res_neff)
# Out:
# [20. 30. 40. 50. 60. 70. 80.]
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 13:04:41.075 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_b1df4f330d380638.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 13:08:13.015 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_2acc0eed9b0e6f26.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 13:11:43.092 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_d962154e91267cc6.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 13:15:13.160 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_0f17ebcb2ce3b492.npz.
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-04-07 13:18:36.429 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_c30b0233581daea5.npz.

# %%
mmi_body_w = 10
lambda_c = 1.55

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=220 * nm, # MMI Body height 
    slab_thickness=0, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='si', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=2, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=55, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.plot_index()
pol = mmi_body_waveguide.fraction_te
print(f'Fracción TE: {pol}')
mmi_body_waveguide.n_eff
# Out:
# 2026-04-09 10:36:51.113 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9dc9691a32a897fc.npz.
# Fracción TE: [0.99999782 0.99999123]
# array([2.82990809+2.20145550e-05j, 2.82673632+2.20484708e-05j])

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 244.34288388947934

# %% [markdown]
# ## MMI 95:05 (rectangular :( ))

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 10  # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.mat_core=mat.si(1.55)
m.MMI_width = mmi_Width
m.wg_width=2.7
m.MMI_num_modes = 40 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.VERBOSE = True
m.find_all_modes()

# 2) Get the L_pi 
L_pi_eme = m.get_L_pi()
# Out:
# [Mode(k: (11.541087323239534+0j), n_eff:(2.8470726990306137+0j)), Mode(k: (11.528315185603025+0j), n_eff:(2.8439219383306282+0j)), Mode(k: (11.506996908231748+0j), n_eff:(2.8386629290367718+0j)), Mode(k: (11.477085394432361+0j), n_eff:(2.831284052858144+0j)), Mode(k: (11.438514801984146+0j), n_eff:(2.821769067166664+0j)), Mode(k: (11.39119843860181+0j), n_eff:(2.810096585828446+0j)), Mode(k: (11.33502956392519+0j), n_eff:(2.796240277046771+0j)), Mode(k: (11.269877412228091+0j), n_eff:(2.780167882203488+0j)), Mode(k: (11.19558793751566+0j), n_eff:(2.7618413996672033+0j)), Mode(k: (11.111982028236316+0j), n_eff:(2.741216644380278+0j)), Mode(k: (11.018850310344321+0j), n_eff:(2.7182419658254946+0j)), Mode(k: (10.915958001260213+0j), n_eff:(2.6928594454503383+0j)), Mode(k: (10.803028901776036+0j), n_eff:(2.6650009476275125+0j)), Mode(k: (10.67975413500992+0j), n_eff:(2.634590275469054+0j)), Mode(k: (10.545781067727118+0j), n_eff:(2.6015404378252307+0j)), Mode(k: (10.400706073609852+0j), n_eff:(2.565751864054405+0j)), Mode(k: (10.244076506185168+0j), n_eff:(2.5271128907249305+0j)), Mode(k: (10.075368120667292+0j), n_eff:(2.4854941918057847+0j)), Mode(k: (9.893992173028305+0j), n_eff:(2.4407505299374663+0j)), Mode(k: (9.699266525327262+0j), n_eff:(2.3927136284009585+0j)), Mode(k: (9.490413898732424+0j), n_eff:(2.3411917401555025+0j)), Mode(k: (9.26653577806387+0j), n_eff:(2.28596321034599+0j)), Mode(k: (9.026592271059387+0j), n_eff:(2.226771507782009+0j)), Mode(k: (8.76938605638884+0j), n_eff:(2.1633212650709113+0j)), Mode(k: (8.493515343966777+0j), n_eff:(2.0952666743897175+0j)), Mode(k: (8.363975732268624+0j), n_eff:(2.0633105266213705+0j)), Mode(k: (8.346931859941742+0j), n_eff:(2.0591059709994823+0j)), Mode(k: (8.318452518043422+0j), n_eff:(2.0520803975388437+0j)), Mode(k: (8.278443061282877+0j), n_eff:(2.0422104581773572+0j)), Mode(k: (8.226749464188066+0j), n_eff:(2.029458156346405+0j)), Mode(k: (8.197367886256174+0j), n_eff:(2.0222100101326697+0j)), Mode(k: (8.163172934000963+0j), n_eff:(2.013774451828347+0j)), Mode(k: (8.087509503650022+0j), n_eff:(1.9951090279533026+0j)), Mode(k: (7.999431020801363+0j), n_eff:(1.9733809327689342+0j)), Mode(k: (7.898603096994682+0j), n_eff:(1.9485076759318687+0j)), Mode(k: (7.879091664071809+0j), n_eff:(1.9436943973873229+0j)), Mode(k: (7.78462044290706+0j), n_eff:(1.9203892765534616+0j)), Mode(k: (7.65699173024763+0j), n_eff:(1.8889045287781463+0j)), Mode(k: (7.536670991596786+0j), n_eff:(1.859222586293384+0j)), Mode(k: (7.515178781589305+0j), n_eff:(1.8539206695293615+0j))]
# Wavelength 1.55  µm
# ---------------------------------------------
# Core refractive index: 3.4750055639285913
# --- Mode #0  --------------------------------
# Effective refractive index: 2.8471+0.0000j
# TE fraction: 1.0000
# TM fraction: 0.0000
# Confinement factor: 0.9880+0.0000j
# --- Mode #1  --------------------------------
# Effective refractive index: 2.8439+0.0000j
# TE fraction: 1.0000
# TM fraction: 0.0000
# Confinement factor: 0.9891+0.0000j
# --- Mode #2  --------------------------------
# Effective refractive index: 2.8387+0.0000j
# TE fraction: 1.0000
# TM fraction: 0.0000
# Confinement factor: 0.9909+0.0000j
# --- Mode #3  --------------------------------
# Effective refractive index: 2.8313+0.0000j
# TE fraction: 1.0000
# TM fraction: 0.0000
# Confinement factor: 0.9934+0.0000j
# --- Mode #4  --------------------------------
# Effective refractive index: 2.8218+0.0000j
# TE fraction: 1.0000
# TM fraction: 0.0000
# Confinement factor: 0.9967+0.0000j
# --- Mode #5  --------------------------------
# Effective refractive index: 2.8101+0.0000j
# TE fraction: 0.9999
# TM fraction: 0.0001
# Confinement factor: 1.0007+0.0000j
# --- Mode #6  --------------------------------
# Effective refractive index: 2.7962+0.0000j
# TE fraction: 0.9999
# TM fraction: 0.0001
# Confinement factor: 1.0056+0.0000j
# --- Mode #7  --------------------------------
# Effective refractive index: 2.7802+0.0000j
# TE fraction: 0.9999
# TM fraction: 0.0001
# Confinement factor: 1.0113+0.0000j
# --- Mode #8  --------------------------------
# Effective refractive index: 2.7618+0.0000j
# TE fraction: 0.9999
# TM fraction: 0.0001
# Confinement factor: 1.0178+0.0000j
# --- Mode #9  --------------------------------
# Effective refractive index: 2.7412+0.0000j
# TE fraction: 0.9998
# TM fraction: 0.0002
# Confinement factor: 1.0253+0.0000j
# --- Mode #10  --------------------------------
# Effective refractive index: 2.7182+0.0000j
# TE fraction: 0.9998
# TM fraction: 0.0002
# Confinement factor: 1.0337+0.0000j
# --- Mode #11  --------------------------------
# Effective refractive index: 2.6929+0.0000j
# TE fraction: 0.9997
# TM fraction: 0.0003
# Confinement factor: 1.0432+0.0000j
# --- Mode #12  --------------------------------
# Effective refractive index: 2.6650+0.0000j
# TE fraction: 0.9996
# TM fraction: 0.0004
# Confinement factor: 1.0539+0.0000j
# --- Mode #13  --------------------------------
# Effective refractive index: 2.6346+0.0000j
# TE fraction: 0.9996
# TM fraction: 0.0004
# Confinement factor: 1.0657+0.0000j
# --- Mode #14  --------------------------------
# Effective refractive index: 2.6015+0.0000j
# TE fraction: 0.9995
# TM fraction: 0.0005
# Confinement factor: 1.0788+0.0000j
# --- Mode #15  --------------------------------
# Effective refractive index: 2.5658+0.0000j
# TE fraction: 0.9994
# TM fraction: 0.0006
# Confinement factor: 1.0934+0.0000j
# --- Mode #16  --------------------------------
# Effective refractive index: 2.5271+0.0000j
# TE fraction: 0.9992
# TM fraction: 0.0008
# Confinement factor: 1.1096+0.0000j
# --- Mode #17  --------------------------------
# Effective refractive index: 2.4855+0.0000j
# TE fraction: 0.9990
# TM fraction: 0.0010
# Confinement factor: 1.1276+0.0000j
# --- Mode #18  --------------------------------
# Effective refractive index: 2.4408+0.0000j
# TE fraction: 0.9988
# TM fraction: 0.0012
# Confinement factor: 1.1475+0.0000j
# --- Mode #19  --------------------------------
# Effective refractive index: 2.3927+0.0000j
# TE fraction: 0.9986
# TM fraction: 0.0014
# Confinement factor: 1.1697+0.0000j
# --- Mode #20  --------------------------------
# Effective refractive index: 2.3412+0.0000j
# TE fraction: 0.9982
# TM fraction: 0.0018
# Confinement factor: 1.1943+0.0000j
# --- Mode #21  --------------------------------
# Effective refractive index: 2.2860+0.0000j
# TE fraction: 0.9978
# TM fraction: 0.0022
# Confinement factor: 1.2218+0.0000j
# --- Mode #22  --------------------------------
# Effective refractive index: 2.2268+0.0000j
# TE fraction: 0.9972
# TM fraction: 0.0028
# Confinement factor: 1.2525+0.0000j
# --- Mode #23  --------------------------------
# Effective refractive index: 2.1633+0.0000j
# TE fraction: 0.9964
# TM fraction: 0.0036
# Confinement factor: 1.2869+0.0000j
# --- Mode #24  --------------------------------
# Effective refractive index: 2.0953+0.0000j
# TE fraction: 0.9953
# TM fraction: 0.0047
# Confinement factor: 1.3256+0.0000j
# --- Mode #25  --------------------------------
# Effective refractive index: 2.0633+0.0000j
# TE fraction: 0.0008
# TM fraction: 0.9992
# Confinement factor: 0.7346+0.0000j
# --- Mode #26  --------------------------------
# Effective refractive index: 2.0591+0.0000j
# TE fraction: 0.0031
# TM fraction: 0.9969
# Confinement factor: 0.7359+0.0000j
# --- Mode #27  --------------------------------
# Effective refractive index: 2.0521+0.0000j
# TE fraction: 0.0070
# TM fraction: 0.9930
# Confinement factor: 0.7381+0.0000j
# --- Mode #28  --------------------------------
# Effective refractive index: 2.0422+0.0000j
# TE fraction: 0.0124
# TM fraction: 0.9876
# Confinement factor: 0.7411+0.0000j
# --- Mode #29  --------------------------------
# Effective refractive index: 2.0295+0.0000j
# TE fraction: 0.0193
# TM fraction: 0.9807
# Confinement factor: 0.7451+0.0000j
# --- Mode #30  --------------------------------
# Effective refractive index: 2.0222+0.0000j
# TE fraction: 0.9936
# TM fraction: 0.0064
# Confinement factor: 1.3691+0.0000j
# --- Mode #31  --------------------------------
# Effective refractive index: 2.0138+0.0000j
# TE fraction: 0.0276
# TM fraction: 0.9724
# Confinement factor: 0.7500+0.0000j
# --- Mode #32  --------------------------------
# Effective refractive index: 1.9951+0.0000j
# TE fraction: 0.0372
# TM fraction: 0.9628
# Confinement factor: 0.7559+0.0000j
# --- Mode #33  --------------------------------
# Effective refractive index: 1.9734+0.0000j
# TE fraction: 0.0480
# TM fraction: 0.9520
# Confinement factor: 0.7629+0.0000j
# --- Mode #34  --------------------------------
# Effective refractive index: 1.9485+0.0000j
# TE fraction: 0.0600
# TM fraction: 0.9400
# Confinement factor: 0.7710+0.0000j
# --- Mode #35  --------------------------------
# Effective refractive index: 1.9437+0.0000j
# TE fraction: 0.9912
# TM fraction: 0.0088
# Confinement factor: 1.4179+0.0000j
# --- Mode #36  --------------------------------
# Effective refractive index: 1.9204+0.0000j
# TE fraction: 0.0731
# TM fraction: 0.9269
# Confinement factor: 0.7803+0.0000j
# --- Mode #37  --------------------------------
# Effective refractive index: 1.8889+0.0000j
# TE fraction: 0.0871
# TM fraction: 0.9129
# Confinement factor: 0.7909+0.0000j
# --- Mode #38  --------------------------------
# Effective refractive index: 1.8592+0.0000j
# TE fraction: 0.9873
# TM fraction: 0.0127
# Confinement factor: 1.4719+0.0000j
# --- Mode #39  --------------------------------
# Effective refractive index: 1.8539+0.0000j
# TE fraction: 0.1020
# TM fraction: 0.8980
# Confinement factor: 0.8029+0.0000j
# ---------------------------------------------
# Cladding refractive index: 1.4577374304687887
# TE number: 28, TM number: 12, n_all: 40
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# n_MODES= 28
# Lπ 2D = 245.97 µm
# [Mode(k: (11.541087323239534+0j), n_eff:(2.8470726990306137+0j)), Mode(k: (11.528315185603025+0j), n_eff:(2.8439219383306282+0j)), Mode(k: (11.506996908231748+0j), n_eff:(2.8386629290367718+0j)), Mode(k: (11.477085394432361+0j), n_eff:(2.831284052858144+0j)), Mode(k: (11.438514801984146+0j), n_eff:(2.821769067166664+0j)), Mode(k: (11.39119843860181+0j), n_eff:(2.810096585828446+0j)), Mode(k: (11.33502956392519+0j), n_eff:(2.796240277046771+0j)), Mode(k: (11.269877412228091+0j), n_eff:(2.780167882203488+0j)), Mode(k: (11.19558793751566+0j), n_eff:(2.7618413996672033+0j)), Mode(k: (11.111982028236316+0j), n_eff:(2.741216644380278+0j)), Mode(k: (11.018850310344321+0j), n_eff:(2.7182419658254946+0j)), Mode(k: (10.915958001260213+0j), n_eff:(2.6928594454503383+0j)), Mode(k: (10.803028901776036+0j), n_eff:(2.6650009476275125+0j)), Mode(k: (10.67975413500992+0j), n_eff:(2.634590275469054+0j)), Mode(k: (10.545781067727118+0j), n_eff:(2.6015404378252307+0j)), Mode(k: (10.400706073609852+0j), n_eff:(2.565751864054405+0j)), Mode(k: (10.244076506185168+0j), n_eff:(2.5271128907249305+0j)), Mode(k: (10.075368120667292+0j), n_eff:(2.4854941918057847+0j)), Mode(k: (9.893992173028305+0j), n_eff:(2.4407505299374663+0j)), Mode(k: (9.699266525327262+0j), n_eff:(2.3927136284009585+0j)), Mode(k: (9.490413898732424+0j), n_eff:(2.3411917401555025+0j)), Mode(k: (9.26653577806387+0j), n_eff:(2.28596321034599+0j)), Mode(k: (9.026592271059387+0j), n_eff:(2.226771507782009+0j)), Mode(k: (8.76938605638884+0j), n_eff:(2.1633212650709113+0j)), Mode(k: (8.493515343966777+0j), n_eff:(2.0952666743897175+0j)), Mode(k: (8.363975732268624+0j), n_eff:(2.0633105266213705+0j)), Mode(k: (8.346931859941742+0j), n_eff:(2.0591059709994823+0j)), Mode(k: (8.318452518043422+0j), n_eff:(2.0520803975388437+0j)), Mode(k: (8.278443061282877+0j), n_eff:(2.0422104581773572+0j)), Mode(k: (8.226749464188066+0j), n_eff:(2.029458156346405+0j)), Mode(k: (8.197367886256174+0j), n_eff:(2.0222100101326697+0j)), Mode(k: (8.163172934000963+0j), n_eff:(2.013774451828347+0j)), Mode(k: (8.087509503650022+0j), n_eff:(1.9951090279533026+0j)), Mode(k: (7.999431020801363+0j), n_eff:(1.9733809327689342+0j)), Mode(k: (7.898603096994682+0j), n_eff:(1.9485076759318687+0j)), Mode(k: (7.879091664071809+0j), n_eff:(1.9436943973873229+0j)), Mode(k: (7.78462044290706+0j), n_eff:(1.9203892765534616+0j)), Mode(k: (7.65699173024763+0j), n_eff:(1.8889045287781463+0j)), Mode(k: (7.536670991596786+0j), n_eff:(1.859222586293384+0j)), Mode(k: (7.515178781589305+0j), n_eff:(1.8539206695293615+0j))]
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %% [markdown]
# en esta parte dnd tengo que decidir donde pongo las guías etc, en el paper de pennings pone que mejor usar la general para el 2x2 que la paired, si no es guiado weakly

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)

m.n_IN =  2 # STUDENT
m.n_OUT = 2 # STUDENT
m.dL_MMI = 0
dy = 0
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = np.array([-1.68, 1.68]) # STUDENT
m.OUT_WVG_positions =np.array([-1.68, 1.68])# STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = L_pi_eme


# Run propagation
m.propagation()
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#   0%|          | 0/4919 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 0.0000
# IO wg width 2.7000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9988
# Total OUT power: 0.9735
# Excess loss [dB] =  0.1164
# ------------------------
# Power over OUTs:  ['0.0001', '0.9735']
# Ratio over OUTs ['0.0001', '0.9999']

# %%
# más optimizado
dy = -0.03

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = np.array([-1.68, 1.68]) + np.array([-dy, dy]) # STUDENT
m.OUT_WVG_positions = np.array([-1.68, 1.68]) + np.array([-dy, dy]) # STUDENT4
m.wg_width = 2.8

# MMI length (check class slides for type of MMI)
m.dL_MMI = 16.65 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.8000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9988
# Total OUT power: 0.5514
# Excess loss [dB] =  2.5852
# ------------------------
# Power over OUTs:  ['0.0275', '0.5239']
# Ratio over OUTs ['0.0499', '0.9501']

# %%
widths = [2.4, 2.5, 2.6, 2.7, 2.8]
mmi_Width = 10

for dw in widths:
    m = MMI_EME() 
    m.mat_core=mat.si(1.55)
    m.MMI_width = mmi_Width
    m.wg_width=dw
    m.MMI_num_modes = 30
    
    m.find_all_modes()
    L_pi_eme = m.get_L_pi()

    m.n_IN = 2 
    m.n_OUT = 2 
    
    dy = 0
    m.IN_WVG_positions = np.array([-1.68, 1.68]) + np.array([-dy, dy])
    m.OUT_WVG_positions = np.array([-1.68, 1.68]) + np.array([-dy, dy])
    
    m.L_MMI = L_pi_eme
    m.dL_MMI = 16.65
    
    m.propagation()
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.4000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9985
# Total OUT power: 0.4420
# Excess loss [dB] =  3.5463
# ------------------------
# Power over OUTs:  ['0.0312', '0.4108']
# Ratio over OUTs ['0.0706', '0.9294']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.5000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9986
# Total OUT power: 0.4701
# Excess loss [dB] =  3.2778
# ------------------------
# Power over OUTs:  ['0.0295', '0.4407']
# Ratio over OUTs ['0.0627', '0.9373']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.6000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9987
# Total OUT power: 0.4977
# Excess loss [dB] =  3.0303
# ------------------------
# Power over OUTs:  ['0.0277', '0.4700']
# Ratio over OUTs ['0.0556', '0.9444']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.7000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9987
# Total OUT power: 0.5243
# Excess loss [dB] =  2.8045
# ------------------------
# Power over OUTs:  ['0.0261', '0.4982']
# Ratio over OUTs ['0.0497', '0.9503']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/5252 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 16.6500
# IO wg width 2.8000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9988
# Total OUT power: 0.5509
# Excess loss [dB] =  2.5892
# ------------------------
# Power over OUTs:  ['0.0245', '0.5264']
# Ratio over OUTs ['0.0445', '0.9555']

# %% [markdown]
# ## MMI 33:33:33

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 10  # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.mat_core=mat.si(1.55)
m.MMI_width = mmi_Width

m.wg_width=2
m.MMI_num_modes = 40 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
#m.VERBOSE = True
m.find_all_modes()

# 2) Get the L_pi 
L_pi_eme = m.get_L_pi()
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)

m.dL_MMI = 0
dy = 0
m.n_IN = 3
m.n_OUT = 3

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = np.array([-3, 0, 3])
m.OUT_WVG_positions =np.array([-3, 0,  3])

# MMI length (check class slides for type of MMI)
m.L_MMI = L_pi_eme


# Run propagation
m.propagation()
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#   0%|          | 0/4919 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment 0.0000
# IO wg width 2.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9988
# Total OUT power: 0.7003
# Excess loss [dB] =  1.5471
# ------------------------
# Power over OUTs:  ['0.1270', '0.2505', '0.3228']
# Ratio over OUTs ['0.1814', '0.3577', '0.4610']

# %%
dy = 0.3

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy, 0, dy]) # STUDENT
m.OUT_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy,0, dy]) # STUDENT4


# MMI length (check class slides for type of MMI)
m.dL_MMI = -3.5 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9983
# Total OUT power: 0.9633
# Excess loss [dB] =  0.1625
# ------------------------
# Power over OUTs:  ['0.3244', '0.3229', '0.3160']
# Ratio over OUTs ['0.3367', '0.3352', '0.3280']

# %%
widths = [2.4, 2.5, 2.6, 2.7, 2.8]
mmi_Width = 10

for dw in widths:
    m = MMI_EME() 
    m.mat_core=mat.si(1.55)
    m.MMI_width = mmi_Width
    m.wg_width=dw
    m.MMI_num_modes = 30
    
    m.find_all_modes()
    L_pi_eme = m.get_L_pi()

    m.n_IN = 3
    m.n_OUT = 3
    
    dy = 0.3
    m.IN_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy, 0, dy])
    m.OUT_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy, 0, dy])
    
    m.L_MMI = L_pi_eme
    m.dL_MMI = -3.5
    
    m.propagation()
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.4000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9987
# Total OUT power: 0.9785
# Excess loss [dB] =  0.0943
# ------------------------
# Power over OUTs:  ['0.3258', '0.3278', '0.3249']
# Ratio over OUTs ['0.3330', '0.3350', '0.3320']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.5000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9988
# Total OUT power: 0.9795
# Excess loss [dB] =  0.0902
# ------------------------
# Power over OUTs:  ['0.3266', '0.3267', '0.3261']
# Ratio over OUTs ['0.3335', '0.3336', '0.3329']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.6000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9989
# Total OUT power: 0.9801
# Excess loss [dB] =  0.0874
# ------------------------
# Power over OUTs:  ['0.3275', '0.3253', '0.3273']
# Ratio over OUTs ['0.3341', '0.3319', '0.3340']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.7000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9990
# Total OUT power: 0.9808
# Excess loss [dB] =  0.0844
# ------------------------
# Power over OUTs:  ['0.3282', '0.3236', '0.3289']
# Ratio over OUTs ['0.3347', '0.3299', '0.3354']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.8000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9991
# Total OUT power: 0.9814
# Excess loss [dB] =  0.0816
# ------------------------
# Power over OUTs:  ['0.3291', '0.3218', '0.3305']
# Ratio over OUTs ['0.3354', '0.3279', '0.3367']

# %%
widths = [2.9, 3]
mmi_Width = 10

for dw in widths:
    m = MMI_EME() 
    m.mat_core=mat.si(1.55)
    m.MMI_width = mmi_Width
    m.wg_width=dw
    m.MMI_num_modes = 30
    
    m.find_all_modes()
    L_pi_eme = m.get_L_pi()

    m.n_IN = 3
    m.n_OUT = 3
    
    dy = 0.3
    m.IN_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy, 0, dy])
    m.OUT_WVG_positions = np.array([-3, 0, 3]) + np.array([-dy, 0, dy])
    
    m.L_MMI = L_pi_eme
    m.dL_MMI = -3.5
    
    m.propagation()
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 2.9000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9992
# Total OUT power: 0.9829
# Excess loss [dB] =  0.0748
# ------------------------
# Power over OUTs:  ['0.3299', '0.3202', '0.3328']
# Ratio over OUTs ['0.3356', '0.3258', '0.3386']
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/4849 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 245.9723
# MMI length increment -3.5000
# IO wg width 3.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9992
# Total OUT power: 0.9841
# Excess loss [dB] =  0.0695
# ------------------------
# Power over OUTs:  ['0.3305', '0.3188', '0.3348']
# Ratio over OUTs ['0.3358', '0.3240', '0.3402']

# %% [markdown]
# # GUÍA DEEP

# %%
lambda_c = 1.55

deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=450 * nm, # Waveguide width
    core_thickness=220 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='si', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=1, # Targeted number of modes to find 
    max_grid_scaling=1.2, # Parameters of the grid 
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

deep_waveguide.plot_index()
deep_waveguide.n_eff.real
# Out:
# 2026-04-27 14:30:00.590 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6c282adc049c36a4.npz.
# array(2.38277127)

# %% [markdown]
# ### Group index

# %%
wl = np.linspace(1.5,1.6, 200)

deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=450 * nm, # Waveguide width
    core_thickness=220 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='si', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=wl, # Wavelength to simulate
    num_modes=1, # Targeted number of modes to find 
    max_grid_scaling=1.2, # Parameters of the grid 
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

neff = deep_waveguide.n_eff.real




ng = neff - wl * np.gradient(neff, wl)

print(ng)
# Out:
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab5-finalproject/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 14:35:32 CEST WARNING: The group index was not computed. To calculate group
#               index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-04-27 14:35:32.370 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_8cea61ed7466ca49.npz.
# [4.28396471 4.28399343 4.28405071 4.28410764 4.28416423 4.28422047
#  4.28427637 4.28433193 4.28438713 4.28444198 4.28449648 4.28455062
#  4.2846044  4.28465783 4.28471089 4.28476359 4.28481593 4.28486789
#  4.28491949 4.28497071 4.28502157 4.28507204 4.28512214 4.28517186
#  4.2852212  4.28527015 4.28531872 4.2853669  4.28541469 4.28546208
#  4.28550909 4.2855557  4.28560191 4.28564772 4.28569313 4.28573813
#  4.28578273 4.28582692 4.2858707  4.28591407 4.28595702 4.28599956
#  4.28604168 4.28608337 4.28612465 4.2861655  4.28620592 4.28624591
#  4.28628547 4.2863246  4.28636329 4.28640155 4.28643937 4.28647674
#  4.28651367 4.28655015 4.28658619 4.28662177 4.28665691 4.28669158
#  4.2867258  4.28675957 4.28679287 4.2868257  4.28685807 4.28688998
#  4.28692141 4.28695237 4.28698286 4.28701287 4.28704241 4.28707146
#  4.28710003 4.28712811 4.28715571 4.28718281 4.28720943 4.28723555
#  4.28726117 4.2872863  4.28731092 4.28733505 4.28735866 4.28738177
#  4.28740437 4.28742646 4.28744803 4.28746909 4.28748963 4.28750964
#  4.28752914 4.2875481  4.28756654 4.28758445 4.28760183 4.28761867
#  4.28763498 4.28765074 4.28766597 4.28768065 4.28769478 4.28770837
#  4.2877214  4.28773389 4.28774581 4.28775718 4.28776799 4.28777823
#  4.28778792 4.28779703 4.28780557 4.28781354 4.28782094 4.28782776
#  4.287834   4.28783967 4.28784474 4.28784923 4.28785313 4.28785645
#  4.28785916 4.28786129 4.28786281 4.28786373 4.28786405 4.28786377
#  4.28786288 4.28786137 4.28785926 4.28785653 4.28785318 4.28784921
#  4.28784462 4.28783941 4.28783357 4.2878271  4.28781999 4.28781226
#  4.28780388 4.28779487 4.28778521 4.28777491 4.28776396 4.28775236
#  4.28774011 4.28772721 4.28771365 4.28769943 4.28768455 4.287669
#  4.28765279 4.28763591 4.28761835 4.28760013 4.28758122 4.28756163
#  4.28754137 4.28752042 4.28749878 4.28747645 4.28745343 4.28742971
#  4.2874053  4.28738019 4.28735437 4.28732785 4.28730062 4.28727269
#  4.28724404 4.28721467 4.28718459 4.28715378 4.28712225 4.28709
#  4.28705702 4.2870233  4.28698886 4.28695368 4.28691775 4.28688109
#  4.28684368 4.28680553 4.28676663 4.28672697 4.28668656 4.2866454
#  4.28660347 4.28656078 4.28651733 4.2864731  4.28642811 4.28638234
#  4.2863358  4.28628848 4.28624038 4.28619149 4.28614182 4.28609135
#  4.2860401  4.28601427]

# %%
print(neff)

# %%
print(wl)

# %%
# índice de grupo a wl=1.55
idx = np.argmin(abs(wl - 1.55))
ng_wl0 = ng[idx]
print(ng_wl0)
# Out:
# 4.287680649808934

# %%
FSR = 1e-5 #um = 10pm
wl0 = 1.55

AL = (wl0**2)/(ng_wl0*FSR)

print(f'AL = {AL}')
# Out:
# AL = 56032.62454042746

# %% [markdown]
# # GAP STUDY (por hacer)

# %%
#espiral (decidir gap o hacer barrido etc)

lambda_c = 1.5

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(0.45, 0.45), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=220 * nm, # Waveguide height 
    gap=600* nm,
    # Materials
    core_material='si', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.2, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_neff = dcoupler_cs.n_eff
#print(f'Índices efectivos: {dcoupler_neff}')

te_frac = dcoupler_cs.fraction_te
print(f'Fracción TE: {te_frac}')

L_pi_TE = 0.5*lambda_c/(dcoupler_neff[0].real-dcoupler_neff[1].real)
print(f'Longitud de Batido TE: {L_pi_TE} um')

#L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
#print(f'Longitud de Batido TM: {L_pi_TM} um')

L = np.linspace(0, 250, 250)

K = np.array(250)
for i in range(250): 
    K= np.sin((1/2)*np.pi*(L/L_pi_TE))**2

plt.plot(L/L_pi_TE, K)
plt.title('L/L_pi vs K')
plt.xlabel('L/L_pi')
plt.ylabel('K')
plt.grid()
plt.show()
